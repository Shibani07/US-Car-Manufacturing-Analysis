# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('car_manufacturing.csv')
df
# Out:
#       Unnamed: 0  price      brand  ...       state  country      condition
# 0              0   6300     toyota  ...  new jersey      usa   10 days left
# 1              1   2899       ford  ...   tennessee      usa    6 days left
# 2              2   5350      dodge  ...     georgia      usa    2 days left
# 3              3  25000       ford  ...    virginia      usa  22 hours left
# 4              4  27700  chevrolet  ...     florida      usa  22 hours left
# ...          ...    ...        ...  ...         ...      ...            ...
# 2494        2494   7800     nissan  ...  california      usa    1 days left
# 2495        2495   9200     nissan  ...     florida      usa  21 hours left
# 2496        2496   9200     nissan  ...     florida      usa  21 hours left
# 2497        2497   9200     nissan  ...     florida      usa    2 days left
# 2498        2498   9200     nissan  ...     florida      usa  21 hours left
#
# [2499 rows x 13 columns]

# %%
del df['Unnamed: 0']
del df['vin']
del df['lot']
del df['condition']

# %%
df.head()
# Out:
#    price      brand    model  year  ...   mileage   color       state country
# 0   6300     toyota  cruiser  2008  ...  274117.0   black  new jersey     usa
# 1   2899       ford       se  2011  ...  190552.0  silver   tennessee     usa
# 2   5350      dodge      mpv  2018  ...   39590.0  silver     georgia     usa
# 3  25000       ford     door  2014  ...   64146.0    blue    virginia     usa
# 4  27700  chevrolet     1500  2018  ...    6654.0     red     florida     usa
#
# [5 rows x 9 columns]

# %% [markdown]
# # **Top 5 Car brands in terms of number of cars**

# %%
df['brand'].unique()
# Out:
# array(['toyota', 'ford', 'dodge', 'chevrolet', 'gmc', 'chrysler', 'kia',
#        'buick', 'infiniti', 'mercedes-benz', 'jeep', 'bmw', 'cadillac',
#        'hyundai', 'mazda', 'honda', 'heartland', 'jaguar', 'acura',
#        'harley-davidson', 'audi', 'lincoln', 'lexus', 'nissan', 'land',
#        'maserati', 'peterbilt', 'ram'], dtype=object)

# %%
data = []
#number of cars of all the brands
for brand in df['brand'].unique():
    data.append([brand , len(df[df['brand']  == brand])])

data
# Out:
# [['toyota', 1],
#  ['ford', 1235],
#  ['dodge', 432],
#  ['chevrolet', 297],
#  ['gmc', 42],
#  ['chrysler', 18],
#  ['kia', 13],
#  ['buick', 13],
#  ['infiniti', 12],
#  ['mercedes-benz', 10],
#  ['jeep', 30],
#  ['bmw', 17],
#  ['cadillac', 10],
#  ['hyundai', 15],
#  ['mazda', 2],
#  ['honda', 12],
#  ['heartland', 5],
#  ['jaguar', 1],
#  ['acura', 3],
#  ['harley-davidson', 1],
#  ['audi', 4],
#  ['lincoln', 2],
#  ['lexus', 2],
#  ['nissan', 312],
#  ['land', 4],
#  ['maserati', 1],
#  ['peterbilt', 4],
#  ['ram', 1]]

# %%
data = pd.DataFrame(data,columns = ['brand','freq'])
data
# Out:
#               brand  freq
# 0            toyota     1
# 1              ford  1235
# 2             dodge   432
# 3         chevrolet   297
# 4               gmc    42
# 5          chrysler    18
# 6               kia    13
# 7             buick    13
# 8          infiniti    12
# 9     mercedes-benz    10
# 10             jeep    30
# 11              bmw    17
# 12         cadillac    10
# 13          hyundai    15
# 14            mazda     2
# 15            honda    12
# 16        heartland     5
# 17           jaguar     1
# 18            acura     3
# 19  harley-davidson     1
# 20             audi     4
# 21          lincoln     2
# 22            lexus     2
# 23           nissan   312
# 24             land     4
# 25         maserati     1
# 26        peterbilt     4
# 27              ram     1

# %%
#for top 5 car brands
data = data.sort_values(by='freq', ascending=False).head()
data
# Out:
#         brand  freq
# 1        ford  1235
# 2       dodge   432
# 23     nissan   312
# 3   chevrolet   297
# 4         gmc    42

# %%
data.plot(x='brand', y='freq', kind='bar')

# %% [markdown]
# # **Car Industry Trend**

# %%
data1 = []

for year in df['year'].unique():
  data1.append([year, len(df[df['year']==year])])

data1 = pd.DataFrame(data1, columns=['year','freq'])
data1
# Out:
#     year  freq
# 0   2008    18
# 1   2011    23
# 2   2018   395
# 3   2014   104
# 4   2010    13
# 5   2017   377
# 6   2009    11
# 7   2013    86
# 8   2015   196
# 9   2020    48
# 10  2016   203
# 11  1973     1
# 12  2003     9
# 13  2019   892
# 14  2002     2
# 15  2000     4
# 16  2001     5
# 17  2005     6
# 18  2012    72
# 19  2006     8
# 20  2007     6
# 21  1998     4
# 22  2004     6
# 23  1994     2
# 24  1997     2
# 25  1996     2
# 26  1999     1
# 27  1984     1
# 28  1995     1
# 29  1993     1

# %%
data1 = data1.sort_values(by='year', ascending = True)
data1
# Out:
#     year  freq
# 11  1973     1
# 27  1984     1
# 29  1993     1
# 23  1994     2
# 28  1995     1
# 25  1996     2
# 24  1997     2
# 21  1998     4
# 26  1999     1
# 15  2000     4
# 16  2001     5
# 14  2002     2
# 12  2003     9
# 22  2004     6
# 17  2005     6
# 19  2006     8
# 20  2007     6
# 0   2008    18
# 6   2009    11
# 4   2010    13
# 1   2011    23
# 18  2012    72
# 7   2013    86
# 3   2014   104
# 8   2015   196
# 10  2016   203
# 5   2017   377
# 2   2018   395
# 13  2019   892
# 9   2020    48

# %%
data1.plot(x = 'year', y = 'freq', kind = 'line')

# %% [markdown]
# # **Most Populat Car Colours**

# %%
data2 = []

for color in df['color'].unique():
    data2.append([color , len(df[df['color']  == color])])

data2 = pd.DataFrame(data2,columns = ['color','freq'])

# %%
data2 = data2.sort_values(by='freq', ascending=False)
data2
# Out:
#                                       color  freq
# 4                                     white   707
# 0                                     black   516
# 5                                      gray   395
# 1                                    silver   300
# 3                                       red   192
# 2                                      blue   151
# 8                                  no_color    61
# 13                                    green    24
# 6                                    orange    20
# 9                                      gold    19
# 10                                 charcoal    18
# 7                                     brown    15
# 17                                   yellow     9
# 31                        magnetic metallic     6
# 30                             shadow black     5
# 18                                   color:     5
# 12                                    beige     5
# 36                             oxford white     4
# ...

# %%
data2.plot(x = 'color', y = 'freq', kind = 'bar', figsize = (20,5))

# %% [markdown]
# # **Which car brand is having Maximum Average Price**

# %%
data3 = df.groupby('brand').mean()['price']
data3
# Out:
# brand
# acura               7266.666667
# audi               13981.250000
# bmw                26397.058824
# buick              19715.769231
# cadillac           24941.000000
# chevrolet          18669.952862
# chrysler           13686.111111
# dodge              17781.988426
# ford               21666.888259
# gmc                10657.380952
# harley-davidson    54680.000000
# heartland           2966.000000
# honda               6127.500000
# hyundai             5203.200000
# infiniti           13098.333333
# jaguar              2800.000000
# jeep               10933.833333
# kia                11123.846154
# land               28900.000000
# lexus              33220.000000
# lincoln            18150.000000
# maserati           30300.000000
# mazda               8000.000000
# mercedes-benz      28704.000000
# nissan             12065.820513
# peterbilt            400.000000
# ram                11050.000000
# toyota              6300.000000
# Name: price, dtype: float64

# %%
data3 = data3.sort_values(ascending = False)
data3
# Out:
# brand
# harley-davidson    54680.000000
# lexus              33220.000000
# maserati           30300.000000
# land               28900.000000
# mercedes-benz      28704.000000
# bmw                26397.058824
# cadillac           24941.000000
# ford               21666.888259
# buick              19715.769231
# chevrolet          18669.952862
# lincoln            18150.000000
# dodge              17781.988426
# audi               13981.250000
# chrysler           13686.111111
# infiniti           13098.333333
# nissan             12065.820513
# kia                11123.846154
# ram                11050.000000
# jeep               10933.833333
# gmc                10657.380952
# mazda               8000.000000
# acura               7266.666667
# toyota              6300.000000
# honda               6127.500000
# hyundai             5203.200000
# heartland           2966.000000
# jaguar              2800.000000
# peterbilt            400.000000
# Name: price, dtype: float64

# %%
data3.plot(x='brand', kind='bar')

# %% [markdown]
# # **Which State is having most expensive cars**

# %%
data4 = df.groupby('state').mean()['price'].sort_values(ascending = False)
data4
# Out:
# state
# kentucky          44969.444444
# ontario           30357.142857
# new mexico        27375.000000
# washington        26771.428571
# illinois          26715.707965
# michigan          23899.822485
# alabama           23872.058824
# nevada            23653.529412
# pennsylvania      22810.210702
# indiana           21391.428571
# nebraska          21350.000000
# mississippi       21148.333333
# wisconsin         21103.191489
# virginia          20041.000000
# oklahoma          19839.084507
# minnesota         18207.352941
# new york          17850.706897
# california        17836.710526
# rhode island      17808.000000
# massachusetts     17650.555556
# ohio              17460.967742
# south carolina    17270.703125
# new hampshire     16757.500000
# north carolina    16485.273973
# tennessee         16259.576923
# new jersey        16209.712644
# missouri          16192.391304
# louisiana         16181.181818
# georgia           16050.313725
# kansas            15500.000000
# ...

# %%
data4.plot.bar(figsize = (15,5))
